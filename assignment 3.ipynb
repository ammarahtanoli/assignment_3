# %% [markdown]
# Write a program that accepts a list from user and print the alternate element of list.

# %%
items1 = input(["enter your items"]).split()
print(items1)
# Out:
# ['rice', 'onion', 'tomato', 'potato', 'chips', 'colddrink', 'icecream', 'chocolates', 'ginger', 'garlic']

# %%
items1[::2]
# Out:
# ['rice', 'tomato', 'chips', 'icecream', 'ginger']

# %% [markdown]
#  Write a program that accepts a list from user. Your program should reverse the content of list and
# display it. Do not use reverse() method.

# %%
items2 = input(["enter your items"]).split()
print(items2)
# Out:
# ['rice', 'potato', 'tomato', 'onion', 'chocolates', 'pasta']

# %%
print(items2[-1:-6:-1])
# Out:
# ['pasta', 'chocolates', 'onion', 'tomato', 'potato']

# %% [markdown]
#  Find and display the largest number of a list without using built-in function max(). Your program
# should ask the user to input values in list from keyboard.

# %%
numbers = input("Enter your numbers: ").split()
print(numbers)
# Out:
# ['25', '04', '07', '24', '04', '05']

# %%
numbers = [int(n) for n in numbers]
print(number1)
# Out:
# [25, 4, 7, 24, 4, 5]

# %%
largest = numbers[0]
for number in numbers:
    if number > largest:
        largest = number
print(largest)
# Out:
# 25

# %% [markdown]
# Write a program that rotates the element of a list so that the element at the first index moves to the
# second index, the element in the second index moves to the third index, etc., and the element in the last
# index moves to the first index.

# %%
items3 = input("Enter list elements separated by space: ").split()
print("Original list:", items3)
first_element = items3[0]
for i in range(len(items3) - 1):
    items3[i] = items3[i + 1]
items3[-1] = first_element
print("Rotated list:", items3)
# Out:
# Original list: ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
# Rotated list: ['b', 'c', 'd', 'e', 'f', 'g', 'h', 'a']

# %% [markdown]
#  Write a program that input a string and ask user to delete a given word from a string.

# %%
text = input("Enter a string: ")
word = input("Enter the word to delete: ")
new_text = text.replace(word, "")
print(new_text)
# Out:
# I want in morning

# %% [markdown]
# Write a program that reads a string from the user containing a date in the form mm/dd/yyyy. It
# should print the date in the form March 12, 2021.

# %%
date_input = input("Enter date (mm/dd/yyyy): ")
month, day, year = date_input.split("/")
months = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]
month_name = months[int(month) - 1]
print(f"{month_name} {int(day)}, {year}")
# Out:
# April 24, 2005

# %% [markdown]
#  Write a program with a function that accepts a string from keyboard and create a new string after
# converting character of each word capitalized. For instance, if the sentence is "stop and smell the roses."
# the output should be "Stop And Smell The Roses"

# %%
text = input("Enter sentence: ")
words = text.split()

for i in range(len(words)):
    words[i] = words[i].capitalize()

print(" ".join(words))
# Out:
# Concentrate On Your Paper

# %% [markdown]
# Find the sum of each row of matrix of size m x n.

# %%
lst1 = [[5, 15],
        [25, 35],
        [45, 55]]

lst2 = [[10, 20],
        [30, 40],
        [50, 60]]

result = []
answer = []

for x in range(len(lst1)):          
    for y in range(len(lst1[x])):   
        answer.append(lst1[x][y] + lst2[x][y])
    
    result.append(answer)
    answer = []                     

print(result)
# Out:
# [[15, 35], [55, 75], [95, 115]]

# %% [markdown]
#  Write a program to add two matrices of size n x m.

# %%
n = int(input("Enter number of rows: "))
m = int(input("Enter number of columns: "))

matrix1 = []
matrix2 = []
result = []

print("Enter elements of first matrix:")
for i in range(n):
    row = []
    for j in range(m):
        row.append(int(input()))
    matrix1.append(row)

print("Enter elements of second matrix:")
for i in range(n):
    row = []
    for j in range(m):
        row.append(int(input()))
    matrix2.append(row)

for i in range(n):
    row = []
    for j in range(m):
        row.append(matrix1[i][j] + matrix2[i][j])
    result.append(row)

print("Resultant Matrix:")
for row in result:
    print(row)
# Out:
# Enter elements of first matrix:
# Enter elements of second matrix:
# Resultant Matrix:
# [105, 127]
# [148, 110]

# %% [markdown]
#  Write a program to multiply two matrices

# %%
a = int(input("Enter A[0][0]: "))
b = int(input("Enter A[0][1]: "))
c = int(input("Enter A[1][0]: "))
d = int(input("Enter A[1][1]: "))

# Second matrix
e = int(input("Enter B[0][0]: "))
f = int(input("Enter B[0][1]: "))
g = int(input("Enter B[1][0]: "))
h = int(input("Enter B[1][1]: "))

# Multiply manually
r1 = a*e + b*g
r2 = a*f + b*h
r3 = c*e + d*g
r4 = c*f + d*h

# Print result
print("Result of multiplication:")
print(r1, r2)
print(r3, r4)
# Out:
# Result of multiplication:
# 36 41
# 64 73
